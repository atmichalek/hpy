# %% [markdown]
# # HLM Python Tutorial

# %% [markdown]
# This notebook will discuss the set up of the HLM python model and provide an example of how to run the model for a test basin.

# %% [markdown]
# # 1. HLM Model 400 (Tetis) background

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Model Set up

# %% [markdown]
# # 3. Forcing data

# %% [markdown]
# # 4. Model Run

# %%
from hlm import HLM
import sys

# %%
instance = HLM()
config_file = '../examples/cedarrapids1/cedar_example2.yaml'
instance.init_from_file(config_file,option_solver=False)
instance.advance()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 instance = HLM()
#       2 config_file = '../examples/cedarrapids1/cedar_example2.yaml'
# ----> 3 instance.init_from_file(config_file,option_solver=False)
#       4 instance.advance()
#
# File c:\Users\am2192\Dropbox (Princeton)\Development\hpy\src\hlm.py:60, in HLM.init_from_file(self, config_file, option_solver)
#      58 self.end_time = d['end_time']
#      59 self.time_step_sec= d['time_step']
# ---> 60 self.network = get_network_from_file(self.configuration)
#      61 # self.states = get_default_states(self.network)
#      62 self.states = get_states_from_manager(d,self.network)
#
# File c:\Users\am2192\Dropbox (Princeton)\Development\hpy\src\utils\network\network.py:69, in get_network_from_file(options)
#      67 prm = options['parameters']
#      68 # flag, f = check_if_pkl_exists(f)
# ...
